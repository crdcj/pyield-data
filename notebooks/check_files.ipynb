# %%
import pandas as pd

# %%
df = pd.read_parquet("../anbima_data.parquet")
df
# Out:
#        BondType ReferenceDate MaturityDate  IndicativeRate
# 0           LFT    2007-01-02   2007-01-10        -0.00015
# 1           LFT    2007-01-02   2007-01-17       -0.000149
# 2           LFT    2007-01-02   2007-02-14       -0.000154
# 3           LFT    2007-01-02   2007-02-21        -0.00015
# 4           LFT    2007-01-02   2007-03-14       -0.000148
# ...         ...           ...          ...             ...
# 220712    NTN-F    2024-12-27   2027-01-01        0.157464
# 220713    NTN-F    2024-12-27   2029-01-01        0.156888
# 220714    NTN-F    2024-12-27   2031-01-01        0.154971
# 220715    NTN-F    2024-12-27   2033-01-01        0.152634
# 220716    NTN-F    2024-12-27   2035-01-01        0.150856
#
# [220717 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 220764 entries, 0 to 220763
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   BondType        220764 non-null  string
#  1   ReferenceDate   220764 non-null  datetime64[ns]
#  2   MaturityDate    220764 non-null  datetime64[ns]
#  3   IndicativeRate  220764 non-null  Float64
# dtypes: Float64(1), datetime64[ns](2), string(1)
# memory usage: 6.9 MB

# %%
rdate = pd.Timestamp("2024-12-23")

df = df.query("ReferenceDate == @rdate").reset_index(drop=True)
df
# Out:
#    BondType ReferenceDate MaturityDate  IndicativeRate
# 0       LFT    2024-12-23   2025-03-01        0.000253
# 1       LFT    2024-12-23   2025-09-01        0.000243
# 2       LFT    2024-12-23   2026-03-01        0.000329
# 3       LFT    2024-12-23   2026-09-01        0.000344
# 4       LFT    2024-12-23   2027-03-01        0.000762
# 5       LFT    2024-12-23   2027-09-01         0.00089
# 6       LFT    2024-12-23   2028-03-01        0.000925
# 7       LFT    2024-12-23   2028-09-01        0.001106
# 8       LFT    2024-12-23   2029-03-01        0.001321
# 9       LFT    2024-12-23   2029-09-01        0.001352
# 10      LFT    2024-12-23   2030-03-01        0.001343
# 11      LFT    2024-12-23   2030-06-01        0.001343
# 12      LFT    2024-12-23   2030-09-01        0.001342
# 13      LFT    2024-12-23   2030-12-01        0.001321
# 14      LTN    2024-12-23   2025-01-01        0.122439
# 15      LTN    2024-12-23   2025-04-01         0.13076
# 16      LTN    2024-12-23   2025-07-01        0.141044
# 17      LTN    2024-12-23   2025-10-01        0.148548
# 18      LTN    2024-12-23   2026-01-01        0.152517
# 19      LTN    2024-12-23   2026-04-01        0.154866
# 20      LTN    2024-12-23   2026-07-01        0.155644
# 21      LTN    2024-12-23   2026-10-01        0.155347
# 22      LTN    2024-12-23   2027-07-01        0.153935
# 23      LTN    2024-12-23   2028-01-01        0.152673
# 24      LTN    2024-12-23   2028-07-01          0.1517
# 25      LTN    2024-12-23   2030-01-01         0.14953
# 26    NTN-B    2024-12-23   2025-05-15        0.046475
# 27    NTN-B    2024-12-23   2026-08-15        0.080361
# 28    NTN-B    2024-12-23   2027-05-15        0.080026
# 29    NTN-B    2024-12-23   2028-08-15        0.079863
# 30    NTN-B    2024-12-23   2029-05-15         0.07701
# 31    NTN-B    2024-12-23   2030-08-15        0.075622
# 32    NTN-B    2024-12-23   2032-08-15          0.0753
# 33    NTN-B    2024-12-23   2033-05-15        0.075039
# 34    NTN-B    2024-12-23   2035-05-15           0.074
# 35    NTN-B    2024-12-23   2040-08-15        0.071147
# 36    NTN-B    2024-12-23   2045-05-15        0.071861
# 37    NTN-B    2024-12-23   2050-08-15        0.072327
# 38    NTN-B    2024-12-23   2055-05-15        0.072263
# 39    NTN-B    2024-12-23   2060-08-15        0.072101
# 40    NTN-C    2024-12-23   2031-01-01        0.067975
# 41    NTN-F    2024-12-23   2025-01-01        0.122483
# 42    NTN-F    2024-12-23   2027-01-01        0.154319
# 43    NTN-F    2024-12-23   2029-01-01        0.151355
# 44    NTN-F    2024-12-23   2031-01-01          0.1487
# 45    NTN-F    2024-12-23   2033-01-01        0.145836
# 46    NTN-F    2024-12-23   2035-01-01        0.144064

# %%
rdate = pd.Timestamp("2024-12-24")

df.query("ReferenceDate == @rdate")
# Out:
# Empty DataFrame
# Columns: [BondType, ReferenceDate, MaturityDate, IndicativeRate]
# Index: []

# %%
# df.to_parquet("../anbima_data.parquet", index=False, compression="gzip")

# %%
df = pd.read_parquet("../di_data.parquet")
df
# Out:
#         TradeDate ExpirationDate TickerSymbol  BDaysToExp  OpenContracts  \
# 0      1995-01-02     1995-02-01      DI1FEV5          22         185169
# 1      1995-01-02     1995-03-01      DI1MAR5          40          12145
# 2      1995-01-02     1995-04-03      DI1ABR5          63            150
# 3      1995-01-03     1995-02-01      DI1FEV5          21         193594
# 4      1995-01-03     1995-03-01      DI1MAR5          39          12295
# ...           ...            ...          ...         ...            ...
# 214885 2024-12-27     2035-01-02       DI1F35        2507         305272
# 214886 2024-12-27     2036-01-02       DI1F36        2756          21978
# 214887 2024-12-27     2037-01-02       DI1F37        3009           4354
# 214888 2024-12-27     2038-01-04       DI1F38        3258           3522
# 214889 2024-12-27     2039-01-03       DI1F39        3509           4241
#
#         TradeCount  TradeVolume  FinancialVolume       DV01  OpenRate  \
# 0              340        45045       2180001225    0.56255   0.44285
# 1               21         1590         74621000   1.019868   0.49064
# 2                0            0                0   1.636827      <NA>
# 3              427        81175       3932939112   0.530598    0.4592
# 4               96        13425        630682950   0.966267   0.49154
# ...            ...          ...              ...        ...       ...
# 214885        4389        15157        387641794  21.887764    0.1459
# 214886           3          596         13375654  21.214564    0.1465
# 214887           8          360          7128869  20.337654    0.1435
# 214888           4          754         13087684  19.304692    0.1445
# 214889           5          801         12160922  18.148303    0.1445
#
#         MinRate  AvgRate  MaxRate  CloseRate  CloseBidRate  CloseAskRate  \
# 0       0.44285  0.45276  0.46003    0.45485          <NA>          <NA>
# 1       0.48964  0.49035  0.49264    0.49014          <NA>          <NA>
# 2          <NA>     <NA>     <NA>       <NA>          <NA>          <NA>
# 3       0.45559  0.45915  0.46463    0.45739          <NA>          <NA>
# 4       0.48643  0.49601  0.50184    0.49565          <NA>          <NA>
# ...         ...      ...      ...        ...           ...           ...
# 214885   0.1446   0.1469   0.1492     0.1492        0.1495        0.1484
# 214886   0.1464   0.1464   0.1465     0.1464          <NA>          <NA>
# 214887   0.1435  0.14525   0.1456     0.1456        0.1481        0.1465
# 214888   0.1445  0.14505   0.1457     0.1457          <NA>          <NA>
# 214889   0.1444  0.14496   0.1456     0.1456         0.147        0.1439
#
#         SettlementRate  SettlementPrice
# 0              0.45721         96766.31
# 1              0.48974         93869.01
# 2              0.45662         91025.65
# 3              0.45949         96898.37
# 4              0.49665         93950.27
# ...                ...              ...
# 214885         0.14831         25264.27
# 214886         0.14728         22254.86
# 214887         0.14658         19529.16
# 214888         0.14629         17116.18
# 214889         0.14629          14939.9
#
# [214890 rows x 18 columns]

# %%
df.query("TradeDate == TradeDate.max()")
df.query("TradeDate == @rdate")
# Out:
# Empty DataFrame
# Columns: [TradeDate, ExpirationDate, TickerSymbol, BDaysToExp, OpenContracts, TradeCount, TradeVolume, FinancialVolume, DV01, OpenRate, MinRate, AvgRate, MaxRate, CloseRate, CloseBidRate, CloseAskRate, SettlementRate, SettlementPrice]
# Index: []

# %%
# df.to_parquet("../di_data.parquet", index=False, compression="gzip")
