# %%
import polars as pl

# URL fixa para o release mais recente (Latest)
BASE_URL = "https://github.com/crdcj/pyield-data/releases/latest/download"

# Para ler o arquivo de B3 Futures
filename = "b3_futures.parquet"
df = pl.read_parquet(f"{BASE_URL}/{filename}")
df
# Out:
# shape: (475_910, 18)
# ┌────────────┬──────────┬─────────┬────────────┬───┬───────────┬───────────┬───────────┬───────────┐
# │ TradDt     ┆ TckrSymb ┆ TradQty ┆ NtlFinVol  ┆ … ┆ AdjstdQtT ┆ AdjstdVal ┆ MaxTradLm ┆ MinTradLm │
# │ ---        ┆ ---      ┆ ---     ┆ ---        ┆   ┆ ax        ┆ Ctrct     ┆ t         ┆ t         │
# │ date       ┆ str      ┆ i64     ┆ f64        ┆   ┆ ---       ┆ ---       ┆ ---       ┆ ---       │
# │            ┆          ┆         ┆            ┆   ┆ f64       ┆ f64       ┆ f64       ┆ f64       │
# ╞════════════╪══════════╪═════════╪════════════╪═══╪═══════════╪═══════════╪═══════════╪═══════════╡
# │ 2018-01-02 ┆ DAPF18   ┆ 4       ┆ 1.2239021e ┆ … ┆ 3.49      ┆ 2.083184  ┆ 6.49      ┆ 0.49      │
# │            ┆          ┆         ┆ 8          ┆   ┆           ┆           ┆           ┆           │
# │ 2018-01-03 ┆ DAPF18   ┆ 4       ┆ 6.121405e7 ┆ … ┆ 3.37      ┆ 5.5395764 ┆ 6.49      ┆ 0.49      │
# │ 2018-01-04 ┆ DAPF18   ┆ 3       ┆ 4.8984904e ┆ … ┆ 3.33      ┆ 1.789577  ┆ 6.37      ┆ 0.37      │
# │            ┆          ┆         ┆ 7          ┆   ┆           ┆           ┆           ┆           │
# │ 2018-01-05 ┆ DAPF18   ┆ 1       ┆ 612464.75  ┆ … ┆ 3.27      ┆ 1.973707  ┆ 6.33      ┆ 0.33      │
# │ 2018-01-08 ┆ DAPF18   ┆ 4       ┆ 3.6758e7   ┆ … ┆ 3.2       ┆ 1.642937  ┆ 6.27      ┆ 0.27      │
# │ …          ┆ …        ┆ …       ┆ …          ┆ … ┆ …         ┆ …         ┆ …         ┆ …         │
# │ 2026-03-23 ┆ WINZ26   ┆ null    ┆ null       ┆ … ┆ null      ┆ 1321.4    ┆ 212500.0  ┆ 173870.0  │
# │ 2026-03-24 ┆ WINZ26   ┆ null    ┆ null       ┆ … ┆ null      ┆ 32.2      ┆ 219770.0  ┆ 179815.0  │
# │ 2026-03-25 ┆ WINZ26   ┆ null    ┆ null       ┆ … ┆ null      ┆ 634.2     ┆ 219945.0  ┆ 179960.0  │
# │ 2026-03-26 ┆ WINZ26   ┆ null    ┆ null       ┆ … ┆ null      ┆ -457.2    ┆ 223435.0  ┆ 182815.0  │
# │ 2026-03-27 ┆ WINZ26   ┆ null    ┆ null       ┆ … ┆ null      ┆ -431.0    ┆ 220920.0  ┆ 180755.0  │
# └────────────┴──────────┴─────────┴────────────┴───┴───────────┴───────────┴───────────┴───────────┘

# %%
df.columns
# Out:
# ['TradDt',
#  'TckrSymb',
#  'TradQty',
#  'NtlFinVol',
#  'OpnIntrst',
#  'FinInstrmQty',
#  'BestBidPric',
#  'BestAskPric',
#  'FrstPric',
#  'MinPric',
#  'MaxPric',
#  'TradAvrgPric',
#  'LastPric',
#  'AdjstdQt',
#  'AdjstdQtTax',
#  'AdjstdValCtrct',
#  'MaxTradLmt',
#  'MinTradLmt']

# %%
df.write_parquet(filename)
