# %%
import polars as pl

# URL fixa para o release mais recente (Latest)
BASE_URL = "https://github.com/crdcj/pyield-data/releases/latest/download"

# Para ler o arquivo de B3 Futures
filename = "b3_futures.parquet"
df = pl.read_parquet(f"{BASE_URL}/{filename}")
df
# Out:
# shape: (476_494, 17)
# ┌────────────┬──────────┬───────────┬─────────┬───┬──────────┬────────────┬────────────┬───────────┐
# │ TradDt     ┆ TckrSymb ┆ OpnIntrst ┆ TradQty ┆ … ┆ AdjstdQt ┆ AdjstdQtTa ┆ MaxTradLmt ┆ MinTradLm │
# │ ---        ┆ ---      ┆ ---       ┆ ---     ┆   ┆ ---      ┆ x          ┆ ---        ┆ t         │
# │ date       ┆ str      ┆ i64       ┆ i64     ┆   ┆ f64      ┆ ---        ┆ f64        ┆ ---       │
# │            ┆          ┆           ┆         ┆   ┆          ┆ f64        ┆            ┆ f64       │
# ╞════════════╪══════════╪═══════════╪═════════╪═══╪══════════╪════════════╪════════════╪═══════════╡
# │ 2018-01-02 ┆ DAPF18   ┆ 70855     ┆ 4       ┆ … ┆ 99877.56 ┆ 3.49       ┆ 6.49       ┆ 0.49      │
# │ 2018-01-02 ┆ DAPF19   ┆ 700       ┆ null    ┆ … ┆ 97172.53 ┆ 2.83       ┆ 5.81       ┆ -0.19     │
# │ 2018-01-02 ┆ DAPG18   ┆ 300       ┆ null    ┆ … ┆ 99629.17 ┆ 3.17       ┆ 6.1        ┆ 0.1       │
# │ 2018-01-02 ┆ DAPH18   ┆ null      ┆ null    ┆ … ┆ 99520.9  ┆ 2.45       ┆ 5.42       ┆ -0.58     │
# │ 2018-01-02 ┆ DAPK19   ┆ 105039    ┆ 5       ┆ … ┆ 96586.33 ┆ 2.6        ┆ 4.67       ┆ 0.67      │
# │ …          ┆ …        ┆ …         ┆ …       ┆ … ┆ …        ┆ …          ┆ …          ┆ …         │
# │ 2026-03-31 ┆ WINQ26   ┆ 34599     ┆ 77      ┆ … ┆ 196462.0 ┆ null       ┆ 210465.0   ┆ 172205.0  │
# │ 2026-03-31 ┆ WINQ27   ┆ null      ┆ null    ┆ … ┆ 222046.0 ┆ null       ┆ 238695.0   ┆ 195300.0  │
# │ 2026-03-31 ┆ WINV26   ┆ null      ┆ null    ┆ … ┆ 200635.0 ┆ null       ┆ 215030.0   ┆ 175940.0  │
# │ 2026-03-31 ┆ WINV27   ┆ null      ┆ null    ┆ … ┆ 226108.0 ┆ null       ┆ 243210.0   ┆ 198995.0  │
# │ 2026-03-31 ┆ WINZ26   ┆ null      ┆ null    ┆ … ┆ 204876.0 ┆ null       ┆ 219695.0   ┆ 179755.0  │
# └────────────┴──────────┴───────────┴─────────┴───┴──────────┴────────────┴────────────┴───────────┘

# %%
df["TradDt"].unique()
# Out:
# shape: (2_047,)
# Series: 'TradDt' [date]
# [
# 	2018-01-02
# 	2018-01-03
# 	2018-01-04
# 	2018-01-05
# 	2018-01-08
# 	…
# 	2026-03-24
# 	2026-03-25
# 	2026-03-26
# 	2026-03-27
# 	2026-03-30
# ]

# %%
df.columns
# Out:
# ['TradDt',
#  'TckrSymb',
#  'OpnIntrst',
#  'TradQty',
#  'FinInstrmQty',
#  'NtlFinVol',
#  'BestBidPric',
#  'BestAskPric',
#  'FrstPric',
#  'MinPric',
#  'MaxPric',
#  'TradAvrgPric',
#  'LastPric',
#  'AdjstdQt',
#  'AdjstdQtTax',
#  'MaxTradLmt',
#  'MinTradLmt']

# %%
df.write_parquet(filename)
